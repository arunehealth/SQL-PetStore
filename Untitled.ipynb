# %%
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline

# %%
data = pd.read_csv('C:\\Users\\Arunakiry Natarajan\\Desktop\\Bank.csv', sep = ';')
data.head (5)
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
data.head(1)
# Out:
#    age         job  marital education default  balance housing loan   contact  \
# 0   30  unemployed  married   primary      no     1787      no   no  cellular
#
#    day month  duration  campaign  pdays  previous poutcome   y
# 0   19   oct        79         1     -1         0  unknown  no

# %%
import seaborn as sns

# %%
sns.countplot(x='y',data=data,palette='hls')
plt.show()

# %%
data.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
data.dropna()
# Out:
#       age            job   marital  education default  balance housing loan  \
# 0      30     unemployed   married    primary      no     1787      no   no
# 1      33       services   married  secondary      no     4789     yes  yes
# 2      35     management    single   tertiary      no     1350     yes   no
# 3      30     management   married   tertiary      no     1476     yes  yes
# 4      59    blue-collar   married  secondary      no        0     yes   no
# 5      35     management    single   tertiary      no      747      no   no
# 6      36  self-employed   married   tertiary      no      307     yes   no
# 7      39     technician   married  secondary      no      147     yes   no
# 8      41   entrepreneur   married   tertiary      no      221     yes   no
# 9      43       services   married    primary      no      -88     yes  yes
# 10     39       services   married  secondary      no     9374     yes   no
# ...

# %%
data.sample()
# Out:
#       age         job  marital  education default  balance housing loan  \
# 1514   32  technician  married  secondary      no      167     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 1514  cellular    8   aug        79         3     -1         0  unknown  no

# %%
x = data.iloc [:,2]
y = data.iloc [:,-1]

# %%
x.value_counts()
# Out:
# married     2797
# single      1196
# divorced     528
# Name: marital, dtype: int64

# %%
#x.unique()

# %%
#x = x.map({'married':1, 'single':2, 'divorced':3})

# %%
#x.head()

# %%
#data.shape

# %%
x = pd.get_dummies(x)

# %% [raw]
# from sklearn.model_selection import train_test_split

# %%
x_train.shape
# Out:
# (3616, 3)

# %%
from sklearn.linear_model import LogisticRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %%
logreg = LogisticRegression()

# %%
logreg.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
logreg.predict(x_test)
# Out:
# array(['no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
# ...

# %%
from sklearn.metrics import confusion_matrix

# %%
#x_predict = classifier.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-3c6b3d1ba608> in <module>()
# ----> 1 x_predict = classifier.predict(x_test)
#
# NameError: name 'classifier' is not defined

# %%
cm = confusion_matrix(y_train,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-a95a9f5914ab> in <module>()
# ----> 1 cm = confusion_matrix(y_train,y_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     248
#     249     """
# --> 250     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     251     if y_type not in ("binary", "multiclass"):
#     252         raise ValueError("%s is not supported" % y_type)
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      69     y_pred : array or indicator matrix
#      70     """
# ---> 71     check_consistent_length(y_true, y_pred)
#      72     type_true = type_of_target(y_true)
#      73     type_pred = type_of_target(y_pred)
#
# ...

# %%
data_only_relevant = data.drop(data.columns[[0,3,5,8,9,10,11,12,13,14]],axis=1)
data_only_relevant.head()
# Out:
#            job  marital default housing loan poutcome   y
# 0   unemployed  married      no      no   no  unknown  no
# 1     services  married      no     yes  yes  failure  no
# 2   management   single      no     yes   no  failure  no
# 3   management  married      no     yes  yes  unknown  no
# 4  blue-collar  married      no     yes   no  unknown  no

# %%
data_indicator=pd.get_dummies(data_only_relevant, columns = 'job'', marital', 'default', 'housing','loan','poutcome','y')
data_indicator
# Out:
#   File "<ipython-input-88-73f7964030cf>", line 1
#     data_indicator=pd.get_dummies(data_only_relevant, columns = 'job'', marital', 'default', 'housing','loan','poutcome','y')
#                                                                                  ^
# SyntaxError: positional argument follows keyword argument
